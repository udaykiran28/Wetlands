# %%
using CSV, DataFrames, DelimitedFiles
data_read = CSV.read("/Users/udaykiran/Library/Mobile Documents/com~apple~CloudDocs/Wetlands/Marshes/Dataset/Hoskote_Lake/Hoskote_birds.csv", DataFrame)
# Out:
# 203856×51 DataFrame
#     Row │ GLOBAL UNIQUE IDENTIFIER           LAST EDITED DATE            TAXON ⋯
#         │ String                             String31                    Int64 ⋯
# ────────┼───────────────────────────────────────────────────────────────────────
#       1 │ URN:CornellLabOfOrnithology:EBIR…  2024-10-22 21:38:07.824425        ⋯
#       2 │ URN:CornellLabOfOrnithology:EBIR…  2024-04-28 17:51:29.157141
#       3 │ URN:CornellLabOfOrnithology:EBIR…  2024-10-22 21:37:26.986427
#       4 │ URN:CornellLabOfOrnithology:EBIR…  2024-10-22 21:36:59.302263
#       5 │ URN:CornellLabOfOrnithology:EBIR…  2024-10-22 22:03:30.884704        ⋯
#       6 │ URN:CornellLabOfOrnithology:EBIR…  2024-10-22 21:37:21.393311
#       7 │ URN:CornellLabOfOrnithology:EBIR…  2024-10-22 21:37:47.050874
#       8 │ URN:CornellLabOfOrnithology:EBIR…  2024-11-23 07:32:13.13963
#    ⋮    │                 ⋮                              ⋮                     ⋱
# ...

# %%
data_copy = copy(data_read)
# Out:
# 203856×51 DataFrame
#     Row │ GLOBAL UNIQUE IDENTIFIER           LAST EDITED DATE            TAXON ⋯
#         │ String                             String31                    Int64 ⋯
# ────────┼───────────────────────────────────────────────────────────────────────
#       1 │ URN:CornellLabOfOrnithology:EBIR…  2024-10-22 21:38:07.824425        ⋯
#       2 │ URN:CornellLabOfOrnithology:EBIR…  2024-04-28 17:51:29.157141
#       3 │ URN:CornellLabOfOrnithology:EBIR…  2024-10-22 21:37:26.986427
#       4 │ URN:CornellLabOfOrnithology:EBIR…  2024-10-22 21:36:59.302263
#       5 │ URN:CornellLabOfOrnithology:EBIR…  2024-10-22 22:03:30.884704        ⋯
#       6 │ URN:CornellLabOfOrnithology:EBIR…  2024-10-22 21:37:21.393311
#       7 │ URN:CornellLabOfOrnithology:EBIR…  2024-10-22 21:37:47.050874
#       8 │ URN:CornellLabOfOrnithology:EBIR…  2024-11-23 07:32:13.13963
#    ⋮    │                 ⋮                              ⋮                     ⋱
# ...

# %%
rename!(data_copy, Symbol("COMMON NAME") => :"COMMON_NAME")
#rename!(data_copy, Symbol("OBSERVATION DATE") => :"OBSERVATION_DATE_YEAR_ONLY")
# Out:
# 203856×51 DataFrame
#     Row │ GLOBAL UNIQUE IDENTIFIER           LAST EDITED DATE            TAXON ⋯
#         │ String                             String31                    Int64 ⋯
# ────────┼───────────────────────────────────────────────────────────────────────
#       1 │ URN:CornellLabOfOrnithology:EBIR…  2024-10-22 21:38:07.824425        ⋯
#       2 │ URN:CornellLabOfOrnithology:EBIR…  2024-04-28 17:51:29.157141
#       3 │ URN:CornellLabOfOrnithology:EBIR…  2024-10-22 21:37:26.986427
#       4 │ URN:CornellLabOfOrnithology:EBIR…  2024-10-22 21:36:59.302263
#       5 │ URN:CornellLabOfOrnithology:EBIR…  2024-10-22 22:03:30.884704        ⋯
#       6 │ URN:CornellLabOfOrnithology:EBIR…  2024-10-22 21:37:21.393311
#       7 │ URN:CornellLabOfOrnithology:EBIR…  2024-10-22 21:37:47.050874
#       8 │ URN:CornellLabOfOrnithology:EBIR…  2024-11-23 07:32:13.13963
#    ⋮    │                 ⋮                              ⋮                     ⋱
# ...

# %%
using Dates

data_copy[!, "OBSERVATION_DATE_YEAR_ONLY"] = year.(data_copy[!, "OBSERVATION_DATE_YEAR_ONLY"])
data_copy
# Out:
# 203856×51 DataFrame
#     Row │ GLOBAL UNIQUE IDENTIFIER           LAST EDITED DATE            TAXON ⋯
#         │ String                             String31                    Int64 ⋯
# ────────┼───────────────────────────────────────────────────────────────────────
#       1 │ URN:CornellLabOfOrnithology:EBIR…  2024-10-22 21:38:07.824425        ⋯
#       2 │ URN:CornellLabOfOrnithology:EBIR…  2024-04-28 17:51:29.157141
#       3 │ URN:CornellLabOfOrnithology:EBIR…  2024-10-22 21:37:26.986427
#       4 │ URN:CornellLabOfOrnithology:EBIR…  2024-10-22 21:36:59.302263
#       5 │ URN:CornellLabOfOrnithology:EBIR…  2024-10-22 22:03:30.884704        ⋯
#       6 │ URN:CornellLabOfOrnithology:EBIR…  2024-10-22 21:37:21.393311
#       7 │ URN:CornellLabOfOrnithology:EBIR…  2024-10-22 21:37:47.050874
#       8 │ URN:CornellLabOfOrnithology:EBIR…  2024-11-23 07:32:13.13963
#    ⋮    │                 ⋮                              ⋮                     ⋱
# ...

# %%
# Remove missing values in COMMON_NAME
# Accessing data of Ashy Woodswallow 

using Chain, Missings


result_AWSwallow = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "Ashy Woodswallow"))
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 9×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       2016      2
#    2 │                       2017      5
#    3 │                       2018      1
#    4 │                       2019     12
#    5 │                       2020      4
#    6 │                       2021     19
#    7 │                       2022      3
#    8 │                       2023      4
#    9 │                       2024      7

# %%
# Remove missing values in COMMON_NAME
# Accessing data of Ashy-crowned Sparrow-Lark 

using Chain, Missings


result_ACSLark = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "Ashy-crowned Sparrow-Lark"))
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 13×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       2010      1
#    2 │                       2013      1
#    3 │                       2014      7
#    4 │                       2015      3
#    5 │                       2016      2
#    6 │                       2017      8
#    7 │                       2018     28
#    8 │                       2019     58
#    9 │                       2020     57
#   10 │                       2021     18
#   11 │                       2022      8
#   12 │                       2023      2
#   13 │                       2024     18

# %%
# Remove missing values in COMMON_NAME
# Accessing data of Jerdon's Bushlark

using Chain, Missings


result_JBLark = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "Jerdon's Bushlark"))
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 14×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       2006      1
#    2 │                       2011      1
#    3 │                       2013      5
#    4 │                       2014     24
#    5 │                       2015     31
#    6 │                       2016    105
#    7 │                       2017     95
#    8 │                       2018    216
#    9 │                       2019    308
#   10 │                       2020    301
#   11 │                       2021    342
#   12 │                       2022    115
#   13 │                       2023    108
#   14 │                       2024    220

# %%
# Remove missing values in COMMON_NAME
# Accessing data of Oriental Skylark

using Chain, Missings


result_OLark = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "Oriental Skylark"))
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 14×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       2009      1
#    2 │                       2011      1
#    3 │                       2013      5
#    4 │                       2014     25
#    5 │                       2015     13
#    6 │                       2016     38
#    7 │                       2017     45
#    8 │                       2018     51
#    9 │                       2019    102
#   10 │                       2020     96
#   11 │                       2021    107
#   12 │                       2022     37
#   13 │                       2023     35
#   14 │                       2024     83

# %%
# Remove missing values in COMMON_NAME
# Accessing data of Rufous-tailed Lark

using Chain, Missings


result_RTLark = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "Rufous-tailed Lark"))
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 6×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       2014      4
#    2 │                       2016      3
#    3 │                       2017      3
#    4 │                       2020      6
#    5 │                       2021      1
#    6 │                       2024      3

# %%
# Remove missing values in COMMON_NAME
# Accessing data of Tawny Lark

using Chain, Missings


result_TLark = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "Tawny Lark"))
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 4×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       2016      2
#    2 │                       2019      4
#    3 │                       2020      5
#    4 │                       2021      1

# %%
# Remove missing values in COMMON_NAME
# Accessing data of Indian Paradise-Flycatcher

using Chain, Missings


result_IPFlycatcher = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "Indian Paradise-Flycatcher"))
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 8×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       2016      1
#    2 │                       2017      4
#    3 │                       2018      2
#    4 │                       2020     21
#    5 │                       2021     16
#    6 │                       2022      1
#    7 │                       2023      9
#    8 │                       2024     30

# %%
# Remove missing values in COMMON_NAME
# Accessing data of Black-headed Cuckooshrike

using Chain, Missings


result_BHCuckooShrike = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "Black-headed Cuckooshrike"))
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 9×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       2016      6
#    2 │                       2017     10
#    3 │                       2018     25
#    4 │                       2019     22
#    5 │                       2020     28
#    6 │                       2021     44
#    7 │                       2022     41
#    8 │                       2023     36
#    9 │                       2024     26

# %%
# Remove missing values in FAMILY
# Accessing data of Ardeidae family

using Chain, Missings


result_IROLLER = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "Indian Roller"))
    dropmissing(_, "OBSERVATION_DATE_YEAR_ONLY")  
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 16×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       1998      1
#    2 │                       2006      1
#    3 │                       2009      1
#    4 │                       2012      1
#    5 │                       2013      8
#    6 │                       2014     34
#    7 │                       2015     44
#    8 │                       2016     97
#    9 │                       2017     92
#   10 │                       2018    146
#   11 │                       2019    232
#   12 │                       2020    177
#   13 │                       2021    229
#   14 │                       2022     38
#   15 │                       2023     47
#   16 │                       2024    109

# %%
# Remove missing values in COMMON_NAME
# Accessing data of European Roller

using Chain, Missings


result_EROLLER = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "European Roller"))
    dropmissing(_, "OBSERVATION_DATE_YEAR_ONLY")  
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 1×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       2021     32

# %%
# Remove missing values in COMMON_NAME
# Accessing data of Eurasian Hoopoe

using Chain, Missings


result_EHoopoe = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "Eurasian Hoopoe"))
    dropmissing(_, "OBSERVATION_DATE_YEAR_ONLY")  
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 14×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       1998      1
#    2 │                       2002      3
#    3 │                       2013      2
#    4 │                       2014      7
#    5 │                       2015     10
#    6 │                       2016     34
#    7 │                       2017     35
#    8 │                       2018    123
#    9 │                       2019    140
#   10 │                       2020    109
#   11 │                       2021     71
#   12 │                       2022     37
#   13 │                       2023     17
#   14 │                       2024     33

# %%
# Remove missing values in COMMON_NAME
# Accessing data of Jerdon's Leafbird

using Chain, Missings


result_JLeafbird = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "Jerdon's Leafbird"))
    dropmissing(_, "OBSERVATION_DATE_YEAR_ONLY")  
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 7×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       2017      1
#    2 │                       2018      2
#    3 │                       2019     10
#    4 │                       2020      5
#    5 │                       2021     12
#    6 │                       2023      1
#    7 │                       2024      4

# %%
# Remove missing values in COMMON_NAME
# Accessing data of Tricolored Munia

using Chain, Missings


result_TMunia = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "Tricolored Munia"))
    dropmissing(_, "OBSERVATION_DATE_YEAR_ONLY")  
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 11×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       2014     16
#    2 │                       2015     22
#    3 │                       2016    103
#    4 │                       2017     66
#    5 │                       2018    173
#    6 │                       2019    185
#    7 │                       2020    177
#    8 │                       2021    120
#    9 │                       2022     13
#   10 │                       2023     44
#   11 │                       2024     98

# %%
# Remove missing values in COMMON_NAME
# Accessing data of White-rumped Munia

using Chain, Missings


result_WRMunia = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "White-rumped Munia"))
    dropmissing(_, "OBSERVATION_DATE_YEAR_ONLY")  
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 7×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       2016      8
#    2 │                       2019      1
#    3 │                       2020      8
#    4 │                       2021     15
#    5 │                       2022     18
#    6 │                       2023      5
#    7 │                       2024      5

# %%
# Remove missing values in COMMON_NAME
# Accessing data of Scaly-breasted Munia

using Chain, Missings


result_SBMunia = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "Scaly-breasted Munia"))
    dropmissing(_, "OBSERVATION_DATE_YEAR_ONLY")  
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 16×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       1998      1
#    2 │                       2002      3
#    3 │                       2009      1
#    4 │                       2012      1
#    5 │                       2013      2
#    6 │                       2014     29
#    7 │                       2015     22
#    8 │                       2016     59
#    9 │                       2017     33
#   10 │                       2018    155
#   11 │                       2019    190
#   12 │                       2020    165
#   13 │                       2021    216
#   14 │                       2022     59
#   15 │                       2023     77
#   16 │                       2024    194

# %%
# Remove missing values in COMMON_NAME
# Accessing data of Red Avadavat

using Chain, Missings


result_RAvadavat = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "Red Avadavat"))
    dropmissing(_, "OBSERVATION_DATE_YEAR_ONLY")  
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 12×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       1998      1
#    2 │                       2014     13
#    3 │                       2015     21
#    4 │                       2016     86
#    5 │                       2017     64
#    6 │                       2018    205
#    7 │                       2019    163
#    8 │                       2020    192
#    9 │                       2021     97
#   10 │                       2022     35
#   11 │                       2023     35
#   12 │                       2024    165

# %%
# Remove missing values in COMMON_NAME
# Accessing data of Indian Silverbill

using Chain, Missings


result_ISilverbill = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "Indian Silverbill"))
    dropmissing(_, "OBSERVATION_DATE_YEAR_ONLY")  
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 15×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       1998      1
#    2 │                       2009      1
#    3 │                       2012      1
#    4 │                       2013      7
#    5 │                       2014     61
#    6 │                       2015     58
#    7 │                       2016    149
#    8 │                       2017     88
#    9 │                       2018    331
#   10 │                       2019    379
#   11 │                       2020    312
#   12 │                       2021    247
#   13 │                       2022     34
#   14 │                       2023     76
#   15 │                       2024    178

# %%
# Remove missing values in COMMON_NAME
# Accessing data of Barred Buttonquail

using Chain, Missings


result_BBQuail = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "Barred Buttonquail"))
    dropmissing(_, "OBSERVATION_DATE_YEAR_ONLY")  
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 11×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       2013      1
#    2 │                       2015      3
#    3 │                       2016      5
#    4 │                       2017      2
#    5 │                       2018     15
#    6 │                       2019     24
#    7 │                       2020     66
#    8 │                       2021     50
#    9 │                       2022     11
#   10 │                       2023      9
#   11 │                       2024     19

# %%
# Remove missing values in COMMON_NAME
# Accessing data of Baya Weaver

using Chain, Missings


result_BWeaver = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "Baya Weaver"))
    dropmissing(_, "OBSERVATION_DATE_YEAR_ONLY")  
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 12×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       2013      1
#    2 │                       2014      8
#    3 │                       2015     27
#    4 │                       2016    126
#    5 │                       2017     86
#    6 │                       2018    218
#    7 │                       2019    241
#    8 │                       2020    273
#    9 │                       2021    264
#   10 │                       2022    102
#   11 │                       2023    127
#   12 │                       2024    221

# %%
# Remove missing values in COMMON_NAME
# Accessing data of Black-breasted Weaver

using Chain, Missings


result_BBWeaver = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "Black-breasted Weaver"))
    dropmissing(_, "OBSERVATION_DATE_YEAR_ONLY")  
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 12×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       2013      3
#    2 │                       2014      3
#    3 │                       2015      1
#    4 │                       2016     17
#    5 │                       2017      8
#    6 │                       2018     28
#    7 │                       2019     39
#    8 │                       2020     63
#    9 │                       2021     23
#   10 │                       2022      2
#   11 │                       2023      2
#   12 │                       2024      7

# %%
# Remove missing values in COMMON_NAME
# Accessing data of Ashy Woodswallow

using Chain, Missings


result_AWSwallow = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "Ashy Woodswallow"))
    dropmissing(_, "OBSERVATION_DATE_YEAR_ONLY")  
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 9×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       2016      2
#    2 │                       2017      5
#    3 │                       2018      1
#    4 │                       2019     12
#    5 │                       2020      4
#    6 │                       2021     19
#    7 │                       2022      3
#    8 │                       2023      4
#    9 │                       2024      7

# %%
# Remove missing values in COMMON_NAME
# Accessing data of Clamorous Reed Warbler

using Chain, Missings


result_CRWarbler = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "Clamorous Reed Warbler"))
    dropmissing(_, "OBSERVATION_DATE_YEAR_ONLY")  
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 13×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       2009      1
#    2 │                       2013      5
#    3 │                       2014     38
#    4 │                       2015     16
#    5 │                       2016    110
#    6 │                       2017     97
#    7 │                       2018    237
#    8 │                       2019    173
#    9 │                       2020    155
#   10 │                       2021    147
#   11 │                       2022     73
#   12 │                       2023     63
#   13 │                       2024     87

# %%
# Remove missing values in COMMON_NAME
# Accessing data of Sykes' Warbler

using Chain, Missings


result_SWarbler = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "Sykes's Warbler"))
    dropmissing(_, "OBSERVATION_DATE_YEAR_ONLY")  
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 14×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       2009      1
#    2 │                       2012      2
#    3 │                       2013      3
#    4 │                       2014     15
#    5 │                       2015     14
#    6 │                       2016     57
#    7 │                       2017     19
#    8 │                       2018    110
#    9 │                       2019    130
#   10 │                       2020    108
#   11 │                       2021    128
#   12 │                       2022     67
#   13 │                       2023     79
#   14 │                       2024    119

# %%
# Remove missing values in COMMON_NAME
# Accessing data of Booted Warbler

using Chain, Missings


result_BWarbler = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "Booted Warbler"))
    dropmissing(_, "OBSERVATION_DATE_YEAR_ONLY")  
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 13×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       2009      1
#    2 │                       2013     12
#    3 │                       2014     29
#    4 │                       2015     18
#    5 │                       2016     80
#    6 │                       2017     80
#    7 │                       2018    158
#    8 │                       2019    172
#    9 │                       2020    151
#   10 │                       2021    165
#   11 │                       2022     97
#   12 │                       2023     85
#   13 │                       2024    164

# %%
# Remove missing values in FAMILY
# Accessing data of Thick-billed Warbler

using Chain, Missings


result_TBWarbler = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "Thick-billed Warbler"))
    dropmissing(_, "OBSERVATION_DATE_YEAR_ONLY")  
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 7×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       2016      3
#    2 │                       2017      4
#    3 │                       2019      1
#    4 │                       2021     10
#    5 │                       2022      3
#    6 │                       2023      6
#    7 │                       2024      1

# %%
# Remove missing values in COMMON_NAME
# Accessing data of India Gray Hornbill

using Chain, Missings


result_IGHornbill = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "Indian Gray Hornbill"))
    dropmissing(_, "OBSERVATION_DATE_YEAR_ONLY")  
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 9×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       2016      3
#    2 │                       2017      1
#    3 │                       2018     11
#    4 │                       2019     14
#    5 │                       2020     20
#    6 │                       2021     14
#    7 │                       2022     12
#    8 │                       2023     21
#    9 │                       2024     33

# %%
# Remove missing values in COMMON_NAME
# Accessing data of Indian Nightjar

using Chain, Missings


result_INightJar = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "Indian Nightjar"))
    dropmissing(_, "OBSERVATION_DATE_YEAR_ONLY")  
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 5×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       2018      7
#    2 │                       2019      5
#    3 │                       2020      3
#    4 │                       2021      4
#    5 │                       2024      5

# %%
# Remove missing values in COMMON_NAME
# Accessing data of Indian Pitta

using Chain, Missings


result_IPitta = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "Indian Pitta"))
    dropmissing(_, "OBSERVATION_DATE_YEAR_ONLY")  
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 5×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       2016      1
#    2 │                       2021      1
#    3 │                       2022      8
#    4 │                       2023     10
#    5 │                       2024     22

# %%
# Remove missing values in COMMON_NAME
# Accessing data of Yellow-eyed Babbler

using Chain, Missings


result_YEBabbler = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "Yellow-eyed Babbler"))
    dropmissing(_, "OBSERVATION_DATE_YEAR_ONLY")  
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 9×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       2016      1
#    2 │                       2017      1
#    3 │                       2018      3
#    4 │                       2019      6
#    5 │                       2020      6
#    6 │                       2021      1
#    7 │                       2022      2
#    8 │                       2023      3
#    9 │                       2024     12

# %%
# Remove missing values in COMMON_NAME
# Accessing data of White-naped Woodpecker

using Chain, Missings


result_WNWoodpecker = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "White-naped Woodpecker"))
    dropmissing(_, "OBSERVATION_DATE_YEAR_ONLY")  
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 4×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       2019      1
#    2 │                       2020      2
#    3 │                       2023      2
#    4 │                       2024      5

# %%
# Remove missing values in COMMON_NAME
# Accessing data of Black-rumped Flameback

using Chain, Missings


result_WNWoodpecker = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "Black-rumped Flameback"))
    dropmissing(_, "OBSERVATION_DATE_YEAR_ONLY")  
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 9×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       2015      2
#    2 │                       2016      2
#    3 │                       2018      3
#    4 │                       2019      9
#    5 │                       2020     16
#    6 │                       2021     14
#    7 │                       2022     20
#    8 │                       2023     14
#    9 │                       2024     34

# %%
# Remove missing values in COMMON_NAME
# Accessing data of Black-headed Bunting

using Chain, Missings


result_WNWoodpecker = @chain data_copy begin
    subset(_, "COMMON_NAME" => ByRow(x -> !ismissing(x) && x == "Black-headed Bunting"))
    dropmissing(_, "OBSERVATION_DATE_YEAR_ONLY")  
    groupby(_, "OBSERVATION_DATE_YEAR_ONLY")
    combine(_, nrow => :count)
end
# Out:
# 4×2 DataFrame
#  Row │ OBSERVATION_DATE_YEAR_ONLY  count
#      │ Int64                       Int64
# ─────┼───────────────────────────────────
#    1 │                       2014      1
#    2 │                       2020     15
#    3 │                       2021      2
#    4 │                       2024      3
